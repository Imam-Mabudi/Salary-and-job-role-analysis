# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import warnings
warnings.filterwarnings('ignore')

#importing the libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # IMPORTING CSV FILE AND DATA WRANGLING

# %%
data = pd.read_csv('SalaryData1.csv')

# %%
data
# Out:
#       Employee ID  Age  Education  Gender  Project Involvement  Job Level  \
# 0               1   42          2  Female                    3          2
# 1               2   50          1    Male                    2          2
# 2               3   38          2    Male                    2          1
# 3               4   34          4  Female                    3          1
# 4               5   28          1    Male                    3          1
# ...           ...  ...        ...     ...                  ...        ...
# 1462         1463   37          2    Male                    4          2
# 1463         1464   40          1    Male                    2          3
# 1464         1465   28          3    Male                    4          2
# 1465         1466   50          3    Male                    2          2
# 1466         1467   35          3    Male                    4          2
#
#                     Job Role  Salary Over 18 years old  Total Working Years  \
# ...

# %%
data.describe()
# Out:
#        Employee ID          Age    Education  Project Involvement  \
# count  1467.000000  1467.000000  1467.000000          1467.000000
# mean    734.000000    37.903885     2.914792             2.729380
# std     423.630735     9.130756     1.024378             0.712184
# min       1.000000    19.000000     1.000000             1.000000
# 25%     367.500000    31.000000     2.000000             2.000000
# 50%     734.000000    37.000000     3.000000             3.000000
# 75%    1100.500000    44.000000     4.000000             3.000000
# max    1467.000000    61.000000     5.000000             4.000000
#
#          Job Level        Salary  Total Working Years  Years At Company  \
# count  1467.000000   1467.000000          1467.000000       1467.000000
# mean      2.064076   6381.319018            11.278800          7.015678
# std       1.108068   4683.567303             7.786851          6.130050
# min       1.000000   1024.000000             0.000000          0.000000
# ...

# %%
data.transpose()
# Out:
#                                      0         1           2         3     \
# Employee ID                             1         2           3         4
# Age                                    42        50          38        34
# Education                               2         1           2         4
# Gender                             Female      Male        Male    Female
# Project Involvement                     3         2           2         3
# Job Level                               2         2           1         1
# Job Role               Business Developer  Engineer  Technician  Engineer
# Salary                               5204      5134        2103      2919
# Over 18 years old                       Y         Y           Y         Y
# Total Working Years                     8        10           7         8
# Years At Company                        6        10           0         8
# Years In Current Role                   4         7           0         7
# ...

# %%
data.shape
# Out:
# (1467, 14)

# %%
data.isnull().sum()
# Out:
# Employee ID                 0
# Age                         0
# Education                   0
# Gender                      0
# Project Involvement         0
# Job Level                   0
# Job Role                    0
# Salary                      0
# Over 18 years old           0
# Total Working Years         0
# Years At Company            0
# Years In Current Role       0
# Unnamed: 12              1467
# Unnamed: 13              1464
# dtype: int64

# %%
data
# Out:
#       Employee ID  Age  Education  Gender  Project Involvement  Job Level  \
# 0               1   42          2  Female                    3          2
# 1               2   50          1    Male                    2          2
# 2               3   38          2    Male                    2          1
# 3               4   34          4  Female                    3          1
# 4               5   28          1    Male                    3          1
# ...           ...  ...        ...     ...                  ...        ...
# 1462         1463   37          2    Male                    4          2
# 1463         1464   40          1    Male                    2          3
# 1464         1465   28          3    Male                    4          2
# 1465         1466   50          3    Male                    2          2
# 1466         1467   35          3    Male                    4          2
#
#                     Job Role  Salary Over 18 years old  Total Working Years  \
# ...

# %% [markdown]
# ## DROPPING SOME COLUMNS TO EASE ANALYSIS

# %%
data.drop('Unnamed: 12', axis=1, inplace=True)

# %%
data.drop('Unnamed: 13', axis=1, inplace=True)

# %%
data
# Out:
#       Employee ID  Age  Education  Gender  Project Involvement  Job Level  \
# 0               1   42          2  Female                    3          2
# 1               2   50          1    Male                    2          2
# 2               3   38          2    Male                    2          1
# 3               4   34          4  Female                    3          1
# 4               5   28          1    Male                    3          1
# ...           ...  ...        ...     ...                  ...        ...
# 1462         1463   37          2    Male                    4          2
# 1463         1464   40          1    Male                    2          3
# 1464         1465   28          3    Male                    4          2
# 1465         1466   50          3    Male                    2          2
# 1466         1467   35          3    Male                    4          2
#
#                     Job Role  Salary Over 18 years old  Total Working Years  \
# ...

# %%
data.value_counts().sum()
# Out:
# 1467

# %% [markdown]
# # DATA VISUALIZATION AND EXPLORATORY ANALYSIS

# %%
data['Age'].value_counts()
# Out:
# 36    78
# 35    77
# 37    69
# 32    69
# 30    68
# 33    61
# 31    60
# 34    58
# 39    58
# 41    57
# 38    50
# 28    48
# 29    48
# 43    46
# 40    42
# 46    40
# 42    39
# 27    39
# 45    33
# 47    33
# 44    32
# 51    30
# 26    26
# 25    26
# 50    24
# 48    24
# 56    22
# 52    19
# 54    19
# 49    19
# 53    18
# 55    17
# 23    16
# 57    14
# 24    14
# 59    14
# 22    13
# 21    11
# 60    10
# 20     9
# 19     8
# 61     5
# 58     4
# Name: Age, dtype: int64

# %%
otal = len(data)
plt.figure(figsize = (35, 15))
plt.title('AGE')
ax = sns.countplot(x = 'Age', data = data)
for p in ax.patches:
    percentage = '{0:.0f}%'.format(p.get_height() / total * 100)
    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 5
    ax.annotate(percentage, (x, y), ha = 'center')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [49], in <cell line: 5>()
#       4 ax = sns.countplot(x = 'Age', data = data)
#       5 for p in ax.patches:
# ----> 6     percentage = '{0:.0f}%'.format(p.get_height() / total * 100)
#       7     x = p.get_x() + p.get_width() / 2
#       8     y = p.get_height() + 5
#
# NameError: name 'total' is not defined

# %%
#for gender

data['Gender'].value_counts().plot(kind='pie')
plt.title('Gender(Pie Chart)', size = 25, color = 'blue')
plt.figure(figsize = (20,10))

# %%
plt.figure(figsize = (8,5))

sns.countplot(data['Gender'])

plt.title('Gender Value Counts')
# Out:
# Text(0.5, 1.0, 'Gender Value Counts')

# %%
# Countplot with percentage for gender

total = len(data)
plt.figure(figsize = (10, 6))
plt.title('Gender')
ax = sns.countplot(x = 'Gender', data = data)
for p in ax.patches:
    percentage = '{0:.0f}%'.format(p.get_height() / total * 100)
    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 5
    ax.annotate(percentage, (x, y), ha = 'center')
plt.show()

# %% [markdown]
# ##### Male are 60% populated while female are 40%

# %%
data
# Out:
#       Employee ID  Age  Education  Gender  Project Involvement  Job Level  \
# 0               1   42          2  Female                    3          2
# 1               2   50          1    Male                    2          2
# 2               3   38          2    Male                    2          1
# 3               4   34          4  Female                    3          1
# 4               5   28          1    Male                    3          1
# ...           ...  ...        ...     ...                  ...        ...
# 1462         1463   37          2    Male                    4          2
# 1463         1464   40          1    Male                    2          3
# 1464         1465   28          3    Male                    4          2
# 1465         1466   50          3    Male                    2          2
# 1466         1467   35          3    Male                    4          2
#
#                     Job Role  Salary Over 18 years old  Total Working Years  \
# ...

# %%
#for Job role

data['Job Role'].value_counts().plot(kind='pie')
plt.title('Job Role(Pie Chart)', size = 35, color = 'blue')
plt.figure(figsize = (30,20))

# %%
total = len(data)
plt.figure(figsize = (18, 6))
plt.title('Job Role')
ax = sns.countplot(x = 'Job Role', data = data)
for p in ax.patches:
    percentage = '{0:.0f}%'.format(p.get_height() / total * 100)
    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 5
    ax.annotate(percentage, (x, y), ha = 'center')
plt.show()

# %% [markdown]
# ### The business developer role have more staff, followed by Engineer and Technician

# %%
otal = len(data)
plt.figure(figsize = (28, 8))
plt.title('Working Years')
ax = sns.countplot(x = 'Total Working Years', data = data)
for p in ax.patches:
    percentage = '{0:.0f}%'.format(p.get_height() / total * 100)
    x = p.get_x() + p.get_width() / 2
    y = p.get_height() + 5
    ax.annotate(percentage, (x, y), ha = 'center')
plt.show()

# %% [markdown]
# ### 10 years is the longest working years, followed by 6 years

# %%
# Exploring the distributions and the relationships between the job role vs the years in common role

plt.figure(figsize = (18, 10))
sns.barplot(x = 'Job Role', y = 'Years In Current Role', data = data)
# Out:
# <AxesSubplot:xlabel='Job Role', ylabel='Years In Current Role'>

# %% [markdown]
# #### The higest years in current job role is Manager followed by RnD Director

# %%
data['Gender'].value_counts()
# Out:
# Male      881
# Female    586
# Name: Gender, dtype: int64

# %%
data['Project Involvement'].value_counts()
# Out:
# 3    865
# 2    375
# 4    144
# 1     83
# Name: Project Involvement, dtype: int64

# %%
# Exploring the distributions and the relationships between the gender vs the job involment

plt.figure(figsize = (18, 10))
sns.barplot(x = 'Gender', y = 'Project Involvement', data = data)
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='Project Involvement'>

# %% [markdown]
# #### There is almost an equal distribution between male and female in the project involvement.

# %%
data
# Out:
#       Employee ID  Age  Education  Gender  Project Involvement  Job Level  \
# 0               1   42          2  Female                    3          2
# 1               2   50          1    Male                    2          2
# 2               3   38          2    Male                    2          1
# 3               4   34          4  Female                    3          1
# 4               5   28          1    Male                    3          1
# ...           ...  ...        ...     ...                  ...        ...
# 1462         1463   37          2    Male                    4          2
# 1463         1464   40          1    Male                    2          3
# 1464         1465   28          3    Male                    4          2
# 1465         1466   50          3    Male                    2          2
# 1466         1467   35          3    Male                    4          2
#
#                     Job Role  Salary Over 18 years old  Total Working Years  \
# ...

# %%
dt = data['Salary'].max()

dt
# Out:
# 20007

# %% [markdown]
# #### The higest salary paid is 20007

# %%
dx = data['Salary'].min()

dx
# Out:
# 1024

# %% [markdown]
# #### The minimum salary is 1024

# %%
dt = data['Years At Company'].max()

dt
# Out:
# 40

# %% [markdown]
# #### The highest working years is 40

# %%
dx = data['Years At Company'].min()

dx
# Out:
# 0

# %% [markdown]
# #### The minimum working year is 0
